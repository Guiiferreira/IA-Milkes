# %% [markdown]
# <a href="https://colab.research.google.com/github/Guiiferreira/IA-Milkes/blob/main/ATIVIDADE_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Inteligência Artificial**
# ---
# **Prof. Milkes Yone Alvarenga**
# ---
#
# **ATIVIDADE 1 - Análise Exploratória de Dados**

# %% [markdown]
# Preparação do Ambiente e Carga de Dados
# Nesta etapa, carregamos os dados e fazemos o tratamento inicial (preenchimento de valores vazios).

# %%
# Importando Bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Lendo a base de Dados a ser utilizada
milsa = pd.read_csv('milsa.csv')

# %%
# Preencher valores nulos em 'Filhos' com 0 (assumindo que NA indica ausência de filhos registrados)
milsa['Filhos'] = milsa['Filhos'].fillna(0)

# %%
display(milsa)
# Out:
#     Funcionario Est.civil      Inst  Filhos  Salario  Anos  Meses    Regiao
# 0             1  solteiro   1o Grau     0.0     4.00    26      3  interior
# 1             2    casado   1o Grau     1.0     4.56    32     10   capital
# 2             3    casado   1o Grau     2.0     5.25    36      5   capital
# 3             4  solteiro   2o Grau     0.0     5.73    20     10     outro
# 4             5  solteiro   1o Grau     0.0     6.26    40      7     outro
# 5             6    casado   1o Grau     0.0     6.66    28      0  interior
# 6             7  solteiro   1o Grau     0.0     6.86    41      0  interior
# 7             8  solteiro   1o Grau     0.0     7.39    43      4   capital
# 8             9    casado   2o Grau     1.0     7.59    34     10   capital
# 9            10  solteiro   2o Grau     0.0     7.44    23      6     outro
# 10           11    casado   2o Grau     2.0     8.12    33      6  interior
# ...

# %% [markdown]
# ## **Primeiras análises do dataset**

# %%
# dimensão do DataFrame (linha, colunas)
milsa.shape
# Out:
# (36, 8)

# %% [markdown]
# ## **Analisando variáveis qualitativas**

# %%
# Quantidade de pessoas no Dataset: Casado e Solteiro.
milsa['Est.civil'].value_counts()
# Out:
# Est.civil
# casado      20
# solteiro    16
# Name: count, dtype: int64

# %%
milsa['Est.civil'].value_counts() / milsa.shape[0]
# Out:
# Est.civil
# casado      0.555556
# solteiro    0.444444
# Name: count, dtype: float64

# %% [markdown]
# ## **Variáveis Quantitativas**
#
# Para analisar variáveis numéricas começamos com estatísticas descritivas (média, mediana, desvio padrão, variância...)

# %%
# Idade
milsa.Anos.count()
# Out:
# np.int64(36)

# %%
milsa.Anos.mean() # média
# Out:
# np.float64(34.583333333333336)

# %%
np.mean(milsa.Anos) # média com numpy
# Out:
# np.float64(34.583333333333336)

# %%
milsa.Anos.var() # variância
# Out:
# 45.39285714285713

# %%
milsa.Anos.std() # desvio padrão
# Out:
# 6.737422143732507

# %%
# Tirando várias estatísticas descritivas de uma só vez
milsa.Anos.describe()
# Out:
# count    36.000000
# mean     34.583333
# std       6.737422
# min      20.000000
# 25%      30.000000
# 50%      34.500000
# 75%      40.000000
# max      48.000000
# Name: Anos, dtype: float64

# %%
milsa.describe()
# Out:
#        Funcionario     Filhos    Salario       Anos      Meses
# count    36.000000  36.000000  36.000000  36.000000  36.000000
# mean     18.500000   0.916667  11.122222  34.583333   5.611111
# std      10.535654   1.250714   4.587458   6.737422   3.288749
# min       1.000000   0.000000   4.000000  20.000000   0.000000
# 25%       9.750000   0.000000   7.552500  30.000000   3.750000
# 50%      18.500000   0.000000  10.165000  34.500000   6.000000
# 75%      27.250000   2.000000  14.060000  40.000000   8.000000
# max      36.000000   5.000000  23.300000  48.000000  11.000000

# %% [markdown]
# Vamos investigar os tipos de dados que há em cada coluna

# %%
milsa.head()
# Out:
#    Funcionario Est.civil     Inst  Filhos  Salario  Anos  Meses    Regiao
# 0            1  solteiro  1o Grau     0.0     4.00    26      3  interior
# 1            2    casado  1o Grau     1.0     4.56    32     10   capital
# 2            3    casado  1o Grau     2.0     5.25    36      5   capital
# 3            4  solteiro  2o Grau     0.0     5.73    20     10     outro
# 4            5  solteiro  1o Grau     0.0     6.26    40      7     outro

# %%
milsa.dtypes
# Out:
# Funcionario      int64
# Est.civil       object
# Inst            object
# Filhos         float64
# Salario        float64
# Anos             int64
# Meses            int64
# Regiao          object
# dtype: object

# %%
# Transformar V4718 e V4720 em float
milsa['Anos'] = pd.to_numeric(milsa['Anos'], errors='coerce')
milsa['Meses'] = pd.to_numeric(milsa['Meses'], errors='coerce')

# %%
milsa.dtypes
# Out:
# Funcionario      int64
# Est.civil       object
# Inst            object
# Filhos         float64
# Salario        float64
# Anos             int64
# Meses            int64
# Regiao          object
# dtype: object

# %% [markdown]
# ## Algumas análises

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Configuração estética dos gráficos

sns.set(style='whitegrid')

# %%
milsa['Anos'] = pd.to_numeric(milsa['Anos'], errors='coerce')
milsa['Salario'] = pd.to_numeric(milsa['Salario'], errors='coerce')

# %%
plt.scatter(milsa.Anos, milsa.Salario)
plt.title("Relação entre idade e renda")
plt.show()

# %% [markdown]
# # **Algumas análises visuais**

# %%
sns.countplot(milsa.Inst)
plt.title("Escolaridade")
plt.xlabel("")
plt.ylabel("Frequência")
plt.show()

# %%
sns.countplot(milsa.Regiao)
plt.title("Região")
plt.show()

# %%
sns.countplot(data=milsa, x="Inst", hue="Regiao")
plt.show()

# %%
# Visualizar as primeiras linhas e informações gerais
display(milsa)
# Out:
#     Funcionario Est.civil      Inst  Filhos  Salario  Anos  Meses    Regiao
# 0             1  solteiro   1o Grau     0.0     4.00    26      3  interior
# 1             2    casado   1o Grau     1.0     4.56    32     10   capital
# 2             3    casado   1o Grau     2.0     5.25    36      5   capital
# 3             4  solteiro   2o Grau     0.0     5.73    20     10     outro
# 4             5  solteiro   1o Grau     0.0     6.26    40      7     outro
# 5             6    casado   1o Grau     0.0     6.66    28      0  interior
# 6             7  solteiro   1o Grau     0.0     6.86    41      0  interior
# 7             8  solteiro   1o Grau     0.0     7.39    43      4   capital
# 8             9    casado   2o Grau     1.0     7.59    34     10   capital
# 9            10  solteiro   2o Grau     0.0     7.44    23      6     outro
# 10           11    casado   2o Grau     2.0     8.12    33      6  interior
# ...

# %% [markdown]
# ### Histograma de Salários

# %%
plt.figure(figsize=(10, 6))
sns.histplot(milsa['Salario'], kde=True, bins=10, color='red')
plt.title('Distribuição de Salários', fontsize=16)
plt.xlabel('Salário')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ### Boxplot: Salário por Instrução

# %%
inst_order = ['1o Grau', '2o Grau', 'Superior']
plt.figure(figsize=(10, 6))
sns.boxplot(x='Inst', y='Salario', data=milsa, order=inst_order, palette='Set2')
plt.title('Salário por Grau de Instrução', fontsize=16)
plt.show()
# Out:
# /tmp/ipython-input-267/1772520701.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Inst', y='Salario', data=milsa, order=inst_order, palette='Set2')

# %% [markdown]
# ## Gráfico de Dispersão: Idade vs Salário

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Anos', y='Salario', hue='Inst', style='Est.civil', data=milsa, s=100)
plt.title('Idade vs Salário por Instrução e Estado Civil', fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Matriz de Correlação (Heatmap)

# %%
# Selecionar apenas colunas numéricas e remover ID do funcionário
numeric_df = milsa.select_dtypes(include=['float64', 'int64']).drop(columns=['Funcionario'])
corr_matrix = numeric_df.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlação', fontsize=16)
plt.show()
